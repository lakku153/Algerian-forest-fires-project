# %% [markdown]
# # Algerian forest fires dataset

# %% [markdown]
# Data Set Information:
#
# The dataset includes 244 instances that regroup a data of two regions of Algeria,namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012. The dataset includes 11 attribues and 1 output attribue (class) The 244 instances have been classified into fire(138 classes) and not fire (106 classes) classes.
#
# Attribute Information:
#
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012) Weather data observations
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8 FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 6. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 7. Drought Code (DC) index from the FWI system: 7 to 220.4
# 8. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 9. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 10. Fire Weather Index (FWI) Index: 0 to 31.1
# 11. Classes: two classes, namely Fire and not Fire

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv')

# %%
pd.set_option('display.max_rows',247)

# %%
data
# Out:
#                                                                                                       Bejaia Region Dataset
# day                           month year Temperature  RH  Ws Rain  FFMC DMC  DC     ISI  BUI  FWI                  Classes
# 01                            06    2012 29          57  18  0     65.7 3.4  7.6    1.3  3.4  0.5                not fire
# 02                            06    2012 29          61  13  1.3   64.4 4.1  7.6    1    3.9  0.4                not fire
# 03                            06    2012 26          82  22  13.1  47.1 2.5  7.1    0.3  2.7  0.1                not fire
# 04                            06    2012 25          89  13  2.5   28.6 1.3  6.9    0    1.7  0                  not fire
# 05                            06    2012 27          77  16  0     64.8 3    14.2   1.2  3.9  0.5                not fire
# 06                            06    2012 31          67  14  0     82.6 5.8  22.2   3.1  7    2.5                    fire
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 247 entries, ('day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI') to ('30', '09', '2012', '24', '64', '15', '0.2', '67.3', '3.8', '16.5', '1.2', '4.8', '0.5')
# Data columns (total 1 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Bejaia Region Dataset   245 non-null    object
# dtypes: object(1)
# memory usage: 49.3+ KB

# %%
data=pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv',header=1)

# %%
data.loc[0]
# Out:
# day                     01
# month                   06
# year                  2012
# Temperature             29
#  RH                     57
#  Ws                     18
# Rain                     0
# FFMC                  65.7
# DMC                    3.4
# DC                     7.6
# ISI                    1.3
# BUI                    3.4
# FWI                    0.5
# Classes        not fire
# Name: 0, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
data.isna().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %% [markdown]
# ### Data cleaning

# %%
data.loc[data.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
data
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 0                               01     06  2012           29   57   18      0
# 1                               02     06  2012           29   61   13    1.3
# 2                               03     06  2012           26   82   22   13.1
# 3                               04     06  2012           25   89   13    2.5
# 4                               05     06  2012           27   77   16      0
# 5                               06     06  2012           31   67   14      0
# 6                               07     06  2012           33   54   13      0
# 7                               08     06  2012           30   73   15      0
# 8                               09     06  2012           25   88   13    0.2
# 9                               10     06  2012           28   79   12      0
# 10                              11     06  2012           31   65   14      0
# ...

# %%
data.loc[:122,"Region"]=0
data.loc[122:,"Region"]=1

# %%
data['Region']=data['Region'].astype(int)

# %%
data.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
data
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC     DC   ISI  \
# 0     01     06  2012           29   57   18      0  65.7   3.4    7.6   1.3
# 1     02     06  2012           29   61   13    1.3  64.4   4.1    7.6     1
# 2     03     06  2012           26   82   22   13.1  47.1   2.5    7.1   0.3
# 3     04     06  2012           25   89   13    2.5  28.6   1.3    6.9     0
# 4     05     06  2012           27   77   16      0  64.8     3   14.2   1.2
# 5     06     06  2012           31   67   14      0  82.6   5.8   22.2   3.1
# 6     07     06  2012           33   54   13      0  88.2   9.9   30.5   6.4
# 7     08     06  2012           30   73   15      0  86.6  12.1   38.3   5.6
# 8     09     06  2012           25   88   13    0.2  52.9   7.9   38.8   0.4
# 9     10     06  2012           28   79   12      0  73.2   9.5   46.3   1.3
# 10    11     06  2012           31   65   14      0  84.5  12.5   54.3     4
# ...

# %%
data.drop(122,inplace=True)

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#      level_0  index day month  year Temperature  RH  Ws Rain   FFMC   DMC  \
# 0          0      0  01    06  2012          29  57  18     0  65.7   3.4
# 1          1      1  02    06  2012          29  61  13   1.3  64.4   4.1
# 2          2      2  03    06  2012          26  82  22  13.1  47.1   2.5
# 3          3      3  04    06  2012          25  89  13   2.5  28.6   1.3
# 4          4      4  05    06  2012          27  77  16     0  64.8     3
# 5          5      5  06    06  2012          31  67  14     0  82.6   5.8
# 6          6      6  07    06  2012          33  54  13     0  88.2   9.9
# 7          7      7  08    06  2012          30  73  15     0  86.6  12.1
# 8          8      8  09    06  2012          25  88  13   0.2  52.9   7.9
# 9          9      9  10    06  2012          28  79  12     0  73.2   9.5
# 10        10     10  11    06  2012          31  65  14     0  84.5  12.5
# 11        11     11  12    06  2012          26  81  19     0    84  13.8
# ...

# %%
data.shape
# Out:
# (243, 17)

# %%
data.columns
# Out:
# Index(['level_0', 'index', 'day', 'month', 'year', 'Temperature', ' RH', ' Ws',
#        'Rain ', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ',
#        'Region'],
#       dtype='object')

# %%
data.columns=data.columns.str.strip()

# %%
data.columns
# Out:
# Index(['level_0', 'index', 'day', 'month', 'year', 'Temperature', 'RH', 'Ws',
#        'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
data.drop(columns=['level_0','index'],inplace=True)

# %%
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC   DMC     DC   ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7   3.4    7.6   1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4   4.1    7.6     1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1   2.5    7.1   0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6   1.3    6.9     0   1.7
# 4    05    06  2012          27  77  16     0  64.8     3   14.2   1.2   3.9
# 5    06    06  2012          31  67  14     0  82.6   5.8   22.2   3.1     7
# 6    07    06  2012          33  54  13     0  88.2   9.9   30.5   6.4  10.9
# 7    08    06  2012          30  73  15     0  86.6  12.1   38.3   5.6  13.5
# 8    09    06  2012          25  88  13   0.2  52.9   7.9   38.8   0.4  10.5
# 9    10    06  2012          28  79  12     0  73.2   9.5   46.3   1.3  12.6
# 10   11    06  2012          31  65  14     0  84.5  12.5   54.3     4  15.8
# ...

# %%
data[['month','day','year','Temperature','RH','Ws']]=data[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: int32(7), object(8)
# memory usage: 22.0+ KB

# %%
obj_cols=data.columns[6:13]

# %%
obj_cols
# Out:
# Index(['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI'], dtype='object')

# %%
for col in obj_cols:
    data[col]=data[col].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %%
data.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
data.to_csv('Algerian_forest_fires_cleaned_Dataset.csv',index=False)

# %% [markdown]
# # Exploratory data analysis

# %%
data.drop(columns=['day','month','year'],inplace=True)

# %%
data.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
data['Classes'].value_counts()
# Out:
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
data['Classes']=data['Classes'].str.strip()

# %%
data['Classes'].value_counts()
# Out:
# fire        137
# not fire    106
# Name: Classes, dtype: int64

# %%
data['Classes'].replace({'not fire':0,'fire':1},inplace=True)

# %%
data.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
data.hist(figsize=(20,14),bins=50)
# Out:
# array([[<Axes: title={'center': 'Temperature'}>,
#         <Axes: title={'center': 'RH'}>, <Axes: title={'center': 'Ws'}>],
#        [<Axes: title={'center': 'Rain'}>,
#         <Axes: title={'center': 'FFMC'}>,
#         <Axes: title={'center': 'DMC'}>],
#        [<Axes: title={'center': 'DC'}>, <Axes: title={'center': 'ISI'}>,
#         <Axes: title={'center': 'BUI'}>],
#        [<Axes: title={'center': 'FWI'}>,
#         <Axes: title={'center': 'Classes'}>,
#         <Axes: title={'center': 'Region'}>]], dtype=object)

# %%
perc=data['Classes'].value_counts(normalize=True)*100
labels=['fire','not fire']
plt.pie(perc,labels=labels,autopct='%1.1f%%')
plt.legend()

# %%
data.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
sns.boxplot(data['FWI'],color='green')
# Out:
# <Axes: >

# %%
temp_df=pd.read_csv('Algerian_forest_fires_cleaned_Dataset.csv')

# %%
temp_df['Classes']=temp_df['Classes'].str.strip()

# %%
temp_df.tail()
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# 238  6.5      fire       1
# 239  0.0  not fire       1
# 240  0.2  not fire       1
# 241  0.7  not fire       1
# 242  0.5  not fire       1

# %%
dftemp=temp_df.loc[temp_df['Region']==0]
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=dftemp)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Bejaia Regions",weight='bold')
plt.tight_layout()

# %%
dftemp=temp_df.loc[temp_df['Region']==1]
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=dftemp)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Sidi-Bel Abbes Regions",weight='bold')
plt.tight_layout()

# %% [markdown]
# #### In Bejaia region, there are maximum chances of getting fire in the month of august
# #### In Sidi-Bel Abbes region, there are maximum chances of getting fire in the month of july and august
